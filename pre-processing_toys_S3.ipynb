# %%
#!pip3 uninstall pymysql

# %%
# !pip3 install pymysql==0.9.3
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: pymysql==0.9.3 in /usr/local/lib/python3.9/site-packages (0.9.3)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
import pymysql

# %%
import boto3
import pandas as pd
import numpy as np
import s3fs

# %%
path1='s3://productscsv/toys.csv'
df=pd.read_csv(path1)
df
# Out:
#                                                  Title  \
# 0                                                  NaN
# 1    Cats vs Pickles - Limited Edition Holiday 12pk...
# 2    Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3    Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4    Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# ..                                                 ...
# 323  Globber ULTIMUM for Kids, Teens, and Adults 3-...
# 324  Magic Drawing Doodle Board for Kids - Ages 3 4...
# 325  Make Your Own DIY Bouncy Ball Craft Kit for Ki...
# 326  Dinosaur Toy Truck for Kids 3-7 with Flash Lig...
# 327  LEGO Speed Champions Aston Martin Valkyrie AMR...
#
#                                                  Image          adeclarative  \
# 0                                                  NaN   Sponsored\n
# 1    https://m.media-amazon.com/images/I/51n8ENJFUW...    4.7 out of 5 stars
# 2    https://m.media-amazon.com/images/I/91SJQup1fq...    4.7 out of 5 stars
# 3    https://m.media-amazon.com/images/I/81G2b5S-wQ...    5.0 out of 5 stars
# 4    https://m.media-amazon.com/images/I/81s0fdVXUu...    4.4 out of 5 stars
# ..                                                 ...                   ...
# 323  https://m.media-amazon.com/images/I/61IxECVec8...    4.6 out of 5 stars
# 324  https://m.media-amazon.com/images/I/614SGUsot9...    3.9 out of 5 stars
# 325  https://m.media-amazon.com/images/I/91YJzf4z9D...    4.5 out of 5 stars
# 326  https://m.media-amazon.com/images/I/81aDx6A2XT...    4.5 out of 5 stars
# 327  https://m.media-amazon.com/images/I/818L58F+ei...    4.8 out of 5 stars
#
#                                        alinknormal_URL asizebase  \
# 0                                                  NaN       NaN
# 1    https://www.amazon.com/gp/slredirect/picassoRe...       282
# 2    https://www.amazon.com/gp/slredirect/picassoRe...     4,333
# 3    https://www.amazon.com/gp/slredirect/picassoRe...         1
# 4    https://www.amazon.com/Jasonwell-Sprinkle-Spri...    11,005
# ..                                                 ...       ...
# 323  https://www.amazon.com/gp/slredirect/picassoRe...       448
# 324  https://www.amazon.com/gp/slredirect/picassoRe...        92
# 325  https://www.amazon.com/gp/slredirect/picassoRe...       630
# 326  https://www.amazon.com/gp/slredirect/picassoRe...        78
# 327  https://www.amazon.com/gp/slredirect/picassoRe...        65
#
#                                        aoffscreen   Price   Price1 asizebase2  \
# 0    Shop Fun Creative Gifts for Boys of All Ages     NaN      NaN        NaN
# 1                                         $54.99    54\n.  $59.99         NaN
# 2                                         $29.99    29\n.      NaN        NaN
# 3                                          $7.99     7\n.      NaN        NaN
# 4                                         $19.99    19\n.  $38.99         NaN
# ..                                            ...     ...      ...        ...
# 323                                      $159.99   159\n.      NaN        NaN
# 324                                        $8.99     8\n.      NaN        NaN
# 325                                       $29.99    29\n.      NaN        NaN
# 326                                       $24.99    24\n.      NaN        NaN
# 327                                       $39.97    39\n.      NaN        NaN
#
#                                                   arow        Like  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4    10% coupon applied at checkoutSave 10%  with c...    Save 10%
# ..                                                 ...         ...
# 323  $8.00 coupon applied at checkoutSave $8.00  wi...  Save $8.00
# 324                                                NaN         NaN
# 325                                                NaN         NaN
# 326                                                NaN         NaN
# 327                                                NaN         NaN
#
#     scouponunclipped__spancontains_class_acolorbase               arow3  \
# 0                                               NaN                 NaN
# 1                                               NaN  Get it as soon as
# 2                                               NaN  Get it as soon as
# 3                                               NaN  Get it as soon as
# 4                                       with coupon  Get it as soon as
# ..                                              ...                 ...
# 323                 with coupon (some sizes/colors)                 NaN
# 324                                             NaN                 NaN
# 325                                             NaN                 NaN
# 326                                             NaN                 NaN
# 327                                             NaN                 NaN
#
#       acolorbase
# 0            NaN
# 1    Sat, Apr 30
# 2    Sat, Apr 30
# 3     Tue, May 3
# 4    Sat, Apr 30
# ..           ...
# 323          NaN
# 324          NaN
# 325          NaN
# 326          NaN
# 327          NaN
#
# [328 rows x 14 columns]

# %%
# limiting these columns
new_df=df[['Title','Image','adeclarative','alinknormal_URL','asizebase','aoffscreen','Price1','arow','Like']]

# %%
#Removing sponsored ad wordings from df
df1=new_df[~new_df.adeclarative.str.contains("Sponsored\n",na=False)]
df1.head()
# Out:
#                                                Title  \
# 1  Cats vs Pickles - Limited Edition Holiday 12pk...
# 2  Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3  Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4  Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# 5  Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old ...
#
#                                                Image        adeclarative  \
# 1  https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2  https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3  https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4  https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5  https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
#
#                                      alinknormal_URL asizebase aoffscreen  \
# 1  https://www.amazon.com/gp/slredirect/picassoRe...       282    $54.99
# 2  https://www.amazon.com/gp/slredirect/picassoRe...     4,333    $29.99
# 3  https://www.amazon.com/gp/slredirect/picassoRe...         1     $7.99
# 4  https://www.amazon.com/Jasonwell-Sprinkle-Spri...    11,005    $19.99
# 5  https://www.amazon.com/Magnetic-Building-Creat...     1,991    $25.97
#
#     Price1                                               arow      Like
# 1  $59.99                                                 NaN       NaN
# 2      NaN                                                NaN       NaN
# 3      NaN                                                NaN       NaN
# 4  $38.99   10% coupon applied at checkoutSave 10%  with c...  Save 10%
# 5  $35.99   20% coupon applied at checkoutSave 20%  with c...  Save 20%

# %%
#Renaming columns withn readble columns names
df1=df1.rename(
        columns={
            'adeclarative':'Rating',
            'Image':'Image',
            'alinknormal_URL':'ProdLink',
            'asizebase':'TotalReviews',
            'aoffscreen':'Price',
            'Price1':'OrgPrice',
            'arow':'CouponsDesc',
            'Like':'CouponsSummery'
               
        })

# %%
df1.head()
# Out:
#                                                Title  \
# 1  Cats vs Pickles - Limited Edition Holiday 12pk...
# 2  Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3  Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4  Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# 5  Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old ...
#
#                                                Image              Rating  \
# 1  https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2  https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3  https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4  https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5  https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
#
#                                             ProdLink TotalReviews    Price  \
# 1  https://www.amazon.com/gp/slredirect/picassoRe...          282  $54.99
# 2  https://www.amazon.com/gp/slredirect/picassoRe...        4,333  $29.99
# 3  https://www.amazon.com/gp/slredirect/picassoRe...            1   $7.99
# 4  https://www.amazon.com/Jasonwell-Sprinkle-Spri...       11,005  $19.99
# 5  https://www.amazon.com/Magnetic-Building-Creat...        1,991  $25.97
#
#   OrgPrice                                        CouponsDesc CouponsSummery
# 1  $59.99                                                 NaN            NaN
# 2      NaN                                                NaN            NaN
# 3      NaN                                                NaN            NaN
# 4  $38.99   10% coupon applied at checkoutSave 10%  with c...       Save 10%
# 5  $35.99   20% coupon applied at checkoutSave 20%  with c...       Save 20%

# %%
df = df1.applymap(lambda x: x.strip() if isinstance(x, str) else x)  
#Any whitespace

# %%
df.tail()
# Out:
#                                                  Title  \
# 323  Globber ULTIMUM for Kids, Teens, and Adults 3-...
# 324  Magic Drawing Doodle Board for Kids - Ages 3 4...
# 325  Make Your Own DIY Bouncy Ball Craft Kit for Ki...
# 326  Dinosaur Toy Truck for Kids 3-7 with Flash Lig...
# 327  LEGO Speed Champions Aston Martin Valkyrie AMR...
#
#                                                  Image              Rating  \
# 323  https://m.media-amazon.com/images/I/61IxECVec8...  4.6 out of 5 stars
# 324  https://m.media-amazon.com/images/I/614SGUsot9...  3.9 out of 5 stars
# 325  https://m.media-amazon.com/images/I/91YJzf4z9D...  4.5 out of 5 stars
# 326  https://m.media-amazon.com/images/I/81aDx6A2XT...  4.5 out of 5 stars
# 327  https://m.media-amazon.com/images/I/818L58F+ei...  4.8 out of 5 stars
#
#                                               ProdLink TotalReviews    Price  \
# 323  https://www.amazon.com/gp/slredirect/picassoRe...          448  $159.99
# 324  https://www.amazon.com/gp/slredirect/picassoRe...           92    $8.99
# 325  https://www.amazon.com/gp/slredirect/picassoRe...          630   $29.99
# 326  https://www.amazon.com/gp/slredirect/picassoRe...           78   $24.99
# 327  https://www.amazon.com/gp/slredirect/picassoRe...           65   $39.97
#
#     OrgPrice                                        CouponsDesc CouponsSummery
# 323      NaN  $8.00 coupon applied at checkoutSave $8.00  wi...     Save $8.00
# 324      NaN                                                NaN            NaN
# 325      NaN                                                NaN            NaN
# 326      NaN                                                NaN            NaN
# 327      NaN                                                NaN            NaN

# %%
cols = df1.select_dtypes(['object']).columns
df1[cols] = df1[cols].apply(lambda x: x.str.strip())
#print(df1.head())
df1.tail()
# Out:
#                                                  Title  \
# 323  Globber ULTIMUM for Kids, Teens, and Adults 3-...
# 324  Magic Drawing Doodle Board for Kids - Ages 3 4...
# 325  Make Your Own DIY Bouncy Ball Craft Kit for Ki...
# 326  Dinosaur Toy Truck for Kids 3-7 with Flash Lig...
# 327  LEGO Speed Champions Aston Martin Valkyrie AMR...
#
#                                                  Image              Rating  \
# 323  https://m.media-amazon.com/images/I/61IxECVec8...  4.6 out of 5 stars
# 324  https://m.media-amazon.com/images/I/614SGUsot9...  3.9 out of 5 stars
# 325  https://m.media-amazon.com/images/I/91YJzf4z9D...  4.5 out of 5 stars
# 326  https://m.media-amazon.com/images/I/81aDx6A2XT...  4.5 out of 5 stars
# 327  https://m.media-amazon.com/images/I/818L58F+ei...  4.8 out of 5 stars
#
#                                               ProdLink TotalReviews    Price  \
# 323  https://www.amazon.com/gp/slredirect/picassoRe...          448  $159.99
# 324  https://www.amazon.com/gp/slredirect/picassoRe...           92    $8.99
# 325  https://www.amazon.com/gp/slredirect/picassoRe...          630   $29.99
# 326  https://www.amazon.com/gp/slredirect/picassoRe...           78   $24.99
# 327  https://www.amazon.com/gp/slredirect/picassoRe...           65   $39.97
#
#     OrgPrice                                        CouponsDesc CouponsSummery
# 323      NaN  $8.00 coupon applied at checkoutSave $8.00  wi...     Save $8.00
# 324      NaN                                                NaN            NaN
# 325      NaN                                                NaN            NaN
# 326      NaN                                                NaN            NaN
# 327      NaN                                                NaN            NaN

# %%
#taking only not null from image, prodlink,title..basically removing null values from title 
df = df1[df1['Image'].notna()]
df = df1[df1['ProdLink'].notna()]
df = df1[df1['Title'].notna()]
df.head()
# Out:
#                                                Title  \
# 1  Cats vs Pickles - Limited Edition Holiday 12pk...
# 2  Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3  Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4  Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# 5  Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old ...
#
#                                                Image              Rating  \
# 1  https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2  https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3  https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4  https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5  https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
#
#                                             ProdLink TotalReviews   Price  \
# 1  https://www.amazon.com/gp/slredirect/picassoRe...          282  $54.99
# 2  https://www.amazon.com/gp/slredirect/picassoRe...        4,333  $29.99
# 3  https://www.amazon.com/gp/slredirect/picassoRe...            1   $7.99
# 4  https://www.amazon.com/Jasonwell-Sprinkle-Spri...       11,005  $19.99
# 5  https://www.amazon.com/Magnetic-Building-Creat...        1,991  $25.97
#
#   OrgPrice                                        CouponsDesc CouponsSummery
# 1   $59.99                                                NaN            NaN
# 2      NaN                                                NaN            NaN
# 3      NaN                                                NaN            NaN
# 4   $38.99  10% coupon applied at checkoutSave 10%  with c...       Save 10%
# 5   $35.99  20% coupon applied at checkoutSave 20%  with c...       Save 20%

# %%
#Handling Nan in Total Reviews, replacing with 0
df['TotalReviews'] = df['TotalReviews'].replace(np.nan, 0)
# Out:
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/2447984689.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalReviews'] = df['TotalReviews'].replace(np.nan, 0)

# %%
#Fill Missing Values of price and original price vice versa
df.Price.fillna(df.OrgPrice, inplace=True)
df.OrgPrice.fillna(df.Price, inplace=True)
df.head()
# Out:
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/1399759672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Price.fillna(df.OrgPrice, inplace=True)
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/1399759672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.OrgPrice.fillna(df.Price, inplace=True)
#                                                Title  \
# 1  Cats vs Pickles - Limited Edition Holiday 12pk...
# 2  Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3  Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4  Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# 5  Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old ...
#
#                                                Image              Rating  \
# 1  https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2  https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3  https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4  https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5  https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
#
#                                             ProdLink TotalReviews   Price  \
# 1  https://www.amazon.com/gp/slredirect/picassoRe...          282  $54.99
# 2  https://www.amazon.com/gp/slredirect/picassoRe...        4,333  $29.99
# 3  https://www.amazon.com/gp/slredirect/picassoRe...            1   $7.99
# 4  https://www.amazon.com/Jasonwell-Sprinkle-Spri...       11,005  $19.99
# 5  https://www.amazon.com/Magnetic-Building-Creat...        1,991  $25.97
#
#   OrgPrice                                        CouponsDesc CouponsSummery
# 1   $59.99                                                NaN            NaN
# 2   $29.99                                                NaN            NaN
# 3    $7.99                                                NaN            NaN
# 4   $38.99  10% coupon applied at checkoutSave 10%  with c...       Save 10%
# 5   $35.99  20% coupon applied at checkoutSave 20%  with c...       Save 20%

# %%
#Print Missing Values for reference
#coupon column, NAN
df[df.isnull().any(axis=1)].head()
# Out:
#                                                 Title  \
# 1   Cats vs Pickles - Limited Edition Holiday 12pk...
# 2   Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3   Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 9       VTech Pop-a-Balls Push & Pop Bulldozer,Yellow
# 10  CENOVE Girls Toys Age 3-6 Year Old Toddler Toy...
#
#                                                 Image              Rating  \
# 1   https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2   https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3   https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 9   https://m.media-amazon.com/images/I/61v9b1kHji...  4.7 out of 5 stars
# 10  https://m.media-amazon.com/images/I/71SL3Pv2u4...  4.8 out of 5 stars
#
#                                              ProdLink TotalReviews   Price  \
# 1   https://www.amazon.com/gp/slredirect/picassoRe...          282  $54.99
# 2   https://www.amazon.com/gp/slredirect/picassoRe...        4,333  $29.99
# 3   https://www.amazon.com/gp/slredirect/picassoRe...            1   $7.99
# 9   https://www.amazon.com/VTech-Pop-a-Balls-Push-...       15,465  $19.69
# 10  https://www.amazon.com/CENOVE-Toddler-Flower-B...        5,096  $35.99
#
#    OrgPrice                                 CouponsDesc CouponsSummery
# 1    $59.99                                         NaN            NaN
# 2    $29.99                                         NaN            NaN
# 3     $7.99                                         NaN            NaN
# 9    $27.99  50% off gift wrap service: code GIFTWRAP50            NaN
# 10   $49.99                                         NaN            NaN

# %%
#Removing Commas in the  Total Reviews and converting them to float
df['TotalReviews'] = df['TotalReviews'].str.replace(',', '').astype(float)
df.tail()
# Out:
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/4275027062.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalReviews'] = df['TotalReviews'].str.replace(',', '').astype(float)
#                                                  Title  \
# 323  Globber ULTIMUM for Kids, Teens, and Adults 3-...
# 324  Magic Drawing Doodle Board for Kids - Ages 3 4...
# 325  Make Your Own DIY Bouncy Ball Craft Kit for Ki...
# 326  Dinosaur Toy Truck for Kids 3-7 with Flash Lig...
# 327  LEGO Speed Champions Aston Martin Valkyrie AMR...
#
#                                                  Image              Rating  \
# 323  https://m.media-amazon.com/images/I/61IxECVec8...  4.6 out of 5 stars
# 324  https://m.media-amazon.com/images/I/614SGUsot9...  3.9 out of 5 stars
# 325  https://m.media-amazon.com/images/I/91YJzf4z9D...  4.5 out of 5 stars
# 326  https://m.media-amazon.com/images/I/81aDx6A2XT...  4.5 out of 5 stars
# 327  https://m.media-amazon.com/images/I/818L58F+ei...  4.8 out of 5 stars
#
#                                               ProdLink  TotalReviews    Price  \
# 323  https://www.amazon.com/gp/slredirect/picassoRe...         448.0  $159.99
# 324  https://www.amazon.com/gp/slredirect/picassoRe...          92.0    $8.99
# 325  https://www.amazon.com/gp/slredirect/picassoRe...         630.0   $29.99
# 326  https://www.amazon.com/gp/slredirect/picassoRe...          78.0   $24.99
# 327  https://www.amazon.com/gp/slredirect/picassoRe...          65.0   $39.97
#
#     OrgPrice                                        CouponsDesc CouponsSummery
# 323  $159.99  $8.00 coupon applied at checkoutSave $8.00  wi...     Save $8.00
# 324    $8.99                                                NaN            NaN
# 325   $29.99                                                NaN            NaN
# 326   $24.99                                                NaN            NaN
# 327   $39.97                                                NaN            NaN

# %%
df.dtypes
# Out:
# Title              object
# Image              object
# Rating             object
# ProdLink           object
# TotalReviews      float64
# Price              object
# OrgPrice           object
# CouponsDesc        object
# CouponsSummery     object
# dtype: object

# %%
import locale
#removing $ from price
locale.setlocale(locale.LC_ALL,'')
df['Price']=df.Price.map(lambda x: locale.atof(x.strip('$')))
df['OrgPrice']=df.OrgPrice.map(lambda x: locale.atof(x.strip('$')))
# Out:
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/1767316431.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=df.Price.map(lambda x: locale.atof(x.strip('$')))
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/1767316431.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OrgPrice']=df.OrgPrice.map(lambda x: locale.atof(x.strip('$')))

# %%
df.head()
# Out:
#                                                Title  \
# 1  Cats vs Pickles - Limited Edition Holiday 12pk...
# 2  Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3  Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4  Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# 5  Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old ...
#
#                                                Image              Rating  \
# 1  https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2  https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3  https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4  https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5  https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
#
#                                             ProdLink  TotalReviews  Price  \
# 1  https://www.amazon.com/gp/slredirect/picassoRe...         282.0  54.99
# 2  https://www.amazon.com/gp/slredirect/picassoRe...        4333.0  29.99
# 3  https://www.amazon.com/gp/slredirect/picassoRe...           1.0   7.99
# 4  https://www.amazon.com/Jasonwell-Sprinkle-Spri...       11005.0  19.99
# 5  https://www.amazon.com/Magnetic-Building-Creat...        1991.0  25.97
#
#    OrgPrice                                        CouponsDesc CouponsSummery
# 1     59.99                                                NaN            NaN
# 2     29.99                                                NaN            NaN
# 3      7.99                                                NaN            NaN
# 4     38.99  10% coupon applied at checkoutSave 10%  with c...       Save 10%
# 5     35.99  20% coupon applied at checkoutSave 20%  with c...       Save 20%

# %%
df['Price'] = pd.to_numeric(df['Price'])
df['OrgPrice'] = pd.to_numeric(df['OrgPrice'])
# Out:
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/2507014352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = pd.to_numeric(df['Price'])
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/2507014352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OrgPrice'] = pd.to_numeric(df['OrgPrice'])

# %%
df.dtypes
# Out:
# Title              object
# Image              object
# Rating             object
# ProdLink           object
# TotalReviews      float64
# Price             float64
# OrgPrice          float64
# CouponsDesc        object
# CouponsSummery     object
# dtype: object

# %%
def create_value(row,price):
    
    if len(str(row))==0:
      return price
    if '%' in row and 'Save' in row:
      return price - (price * float(row.split(" ")[1].split("%")[0])/100)
    elif '$' in row:
       return price - float(row.split('$')[1])
    else:
        return price


df['CouponPrice'] = df.apply(lambda row: create_value(row['CouponsSummery'],row['Price']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 13>()
#       9     else:
#      10         return price
# ---> 13 df['CouponPrice'] = df.apply(lambda row: create_value(row['CouponsSummery'],row['Price']), axis=1)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [23], in <lambda>(row)
#       9     else:
#      10         return price
# ---> 13 df['CouponPrice'] = df.apply(lambda row: create_value(row['CouponsSummery'],row['Price']), axis=1)
#
# Input In [23], in create_value(row, price)
#       3 if len(str(row))==0:
#       4   return price
# ----> 5 if '%' in row and 'Save' in row:
#       6   return price - (price * float(row.split(" ")[1].split("%")[0])/100)
#       7 elif '$' in row:
#
# TypeError: argument of type 'float' is not iterable

# %%
 df['PercentReduction'] = df.apply(lambda row: abs(((row.CouponPrice - row.OrgPrice)/row.OrgPrice) * 100), axis=1)
 df.head(10)
# Out:
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/3785541528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PercentReduction'] = df.apply(lambda row: abs(((row.CouponPrice - row.OrgPrice)/row.OrgPrice) * 100), axis=1)
#                                                 Title  \
# 1   Cats vs Pickles - Limited Edition Holiday 12pk...
# 2   Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3   Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4   Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# 5   Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old ...
# 7   Kids Toys Stem Dinosaur Toy: Take Apart Dinosa...
# 8   Toys for 3-8 Year Old Girls,Timer Rotation Sta...
# 9       VTech Pop-a-Balls Push & Pop Bulldozer,Yellow
# 10  CENOVE Girls Toys Age 3-6 Year Old Toddler Toy...
# 11  Laradola Dinosaur Toys for 3 4 5 6 7 8 Year Ol...
#
#                                                 Image              Rating  \
# 1   https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2   https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3   https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4   https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5   https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
# 7   https://m.media-amazon.com/images/I/81mnHgAWL0...  4.6 out of 5 stars
# 8   https://m.media-amazon.com/images/I/61EWOPFU2f...  4.4 out of 5 stars
# 9   https://m.media-amazon.com/images/I/61v9b1kHji...  4.7 out of 5 stars
# 10  https://m.media-amazon.com/images/I/71SL3Pv2u4...  4.8 out of 5 stars
# 11  https://m.media-amazon.com/images/I/81SFRhIo8T...  4.6 out of 5 stars
#
#                                              ProdLink  TotalReviews  Price  \
# 1   https://www.amazon.com/gp/slredirect/picassoRe...         282.0  54.99
# 2   https://www.amazon.com/gp/slredirect/picassoRe...        4333.0  29.99
# 3   https://www.amazon.com/gp/slredirect/picassoRe...           1.0   7.99
# 4   https://www.amazon.com/Jasonwell-Sprinkle-Spri...       11005.0  19.99
# 5   https://www.amazon.com/Magnetic-Building-Creat...        1991.0  25.97
# 7   https://www.amazon.com/Kids-Toys-Stem-Dinosaur...        2950.0  25.99
# 8   https://www.amazon.com/Projection-Christmas-Bi...        3388.0  25.98
# 9   https://www.amazon.com/VTech-Pop-a-Balls-Push-...       15465.0  19.69
# 10  https://www.amazon.com/CENOVE-Toddler-Flower-B...        5096.0  35.99
# 11  https://www.amazon.com/Dinosaur-Construction-B...        7423.0  25.99
#
#     OrgPrice                                        CouponsDesc  \
# 1      59.99                                                NaN
# 2      29.99                                                NaN
# 3       7.99                                                NaN
# 4      38.99  10% coupon applied at checkoutSave 10%  with c...
# 5      35.99  20% coupon applied at checkoutSave 20%  with c...
# 7      25.99  $8.00 coupon applied at checkoutSave $8.00  wi...
# 8      39.99  20% coupon applied at checkoutSave 20%  with c...
# 9      27.99         50% off gift wrap service: code GIFTWRAP50
# 10     49.99                                                NaN
# 11     25.99  $7.00 coupon applied at checkoutSave $7.00  wi...
#
#    CouponsSummery  CouponPrice  PercentReduction
# 1             NaN         5.00         91.665278
# 2             NaN         0.00        100.000000
# 3             NaN         0.00        100.000000
# 4        Save 10%        19.00         51.269556
# 5        Save 20%        10.02         72.158933
# 7      Save $8.00         0.00        100.000000
# 8        Save 20%        14.01         64.966242
# 9             NaN         8.30         70.346552
# 10            NaN        14.00         71.994399
# 11     Save $7.00         0.00        100.000000

# %%
# Out:
# /var/folders/3c/hxpmknwd5cg9lwydrkf402qw0000gp/T/ipykernel_19357/1389658134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CouponPrice']=df['OrgPrice']-df['Price']
#                                                Title  \
# 1  Cats vs Pickles - Limited Edition Holiday 12pk...
# 2  Osmo - Super Studio Disney Frozen 2 - Ages 5-1...
# 3  Pop it Pink Ombre Cupcake Fidget Toy Girls and...
# 4  Jasonwell Splash Pad Sprinkler for Kids 68" Sp...
# 5  Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old ...
#
#                                                Image              Rating  \
# 1  https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2  https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3  https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4  https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5  https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
#
#                                             ProdLink  TotalReviews  Price  \
# 1  https://www.amazon.com/gp/slredirect/picassoRe...         282.0  54.99
# 2  https://www.amazon.com/gp/slredirect/picassoRe...        4333.0  29.99
# 3  https://www.amazon.com/gp/slredirect/picassoRe...           1.0   7.99
# 4  https://www.amazon.com/Jasonwell-Sprinkle-Spri...       11005.0  19.99
# 5  https://www.amazon.com/Magnetic-Building-Creat...        1991.0  25.97
#
#    OrgPrice                                        CouponsDesc CouponsSummery  \
# 1     59.99                                                NaN            NaN
# 2     29.99                                                NaN            NaN
# 3      7.99                                                NaN            NaN
# 4     38.99  10% coupon applied at checkoutSave 10%  with c...       Save 10%
# 5     35.99  20% coupon applied at checkoutSave 20%  with c...       Save 20%
#
#    CouponPrice
# 1         5.00
# 2         0.00
# 3         0.00
# 4        19.00
# 5        10.02

# %%
df1['Title']=df['Title'].str.split(',',0)
df1.head(10)
# Out:
#                                                 Title  \
# 1   [Cats vs Pickles - Limited Edition Holiday 12p...
# 2   [Osmo - Super Studio Disney Frozen 2 - Ages 5-...
# 3   [Pop it Pink Ombre Cupcake Fidget Toy Girls an...
# 4   [Jasonwell Splash Pad Sprinkler for Kids 68" S...
# 5   [Magnetic Tiles Toys for 3 4 5 6 7 8+ Year Old...
# 6                                                 NaN
# 7   [Kids Toys Stem Dinosaur Toy: Take Apart Dinos...
# 8   [Toys for 3-8 Year Old Girls, Timer Rotation S...
# 9    [VTech Pop-a-Balls Push & Pop Bulldozer, Yellow]
# 10  [CENOVE Girls Toys Age 3-6 Year Old Toddler To...
#
#                                                 Image              Rating  \
# 1   https://m.media-amazon.com/images/I/51n8ENJFUW...  4.7 out of 5 stars
# 2   https://m.media-amazon.com/images/I/91SJQup1fq...  4.7 out of 5 stars
# 3   https://m.media-amazon.com/images/I/81G2b5S-wQ...  5.0 out of 5 stars
# 4   https://m.media-amazon.com/images/I/81s0fdVXUu...  4.4 out of 5 stars
# 5   https://m.media-amazon.com/images/I/71DQtErS2T...  4.6 out of 5 stars
# 6                                                 NaN                 NaN
# 7   https://m.media-amazon.com/images/I/81mnHgAWL0...  4.6 out of 5 stars
# 8   https://m.media-amazon.com/images/I/61EWOPFU2f...  4.4 out of 5 stars
# 9   https://m.media-amazon.com/images/I/61v9b1kHji...  4.7 out of 5 stars
# 10  https://m.media-amazon.com/images/I/71SL3Pv2u4...  4.8 out of 5 stars
#
#                                              ProdLink TotalReviews   Price  \
# 1   https://www.amazon.com/gp/slredirect/picassoRe...          282  $54.99
# 2   https://www.amazon.com/gp/slredirect/picassoRe...        4,333  $29.99
# 3   https://www.amazon.com/gp/slredirect/picassoRe...            1   $7.99
# 4   https://www.amazon.com/Jasonwell-Sprinkle-Spri...       11,005  $19.99
# 5   https://www.amazon.com/Magnetic-Building-Creat...        1,991  $25.97
# 6                                                 NaN          NaN     NaN
# 7   https://www.amazon.com/Kids-Toys-Stem-Dinosaur...        2,950  $25.99
# 8   https://www.amazon.com/Projection-Christmas-Bi...        3,388  $25.98
# 9   https://www.amazon.com/VTech-Pop-a-Balls-Push-...       15,465  $19.69
# 10  https://www.amazon.com/CENOVE-Toddler-Flower-B...        5,096  $35.99
#
#    OrgPrice                                        CouponsDesc CouponsSummery
# 1    $59.99                                                NaN            NaN
# 2       NaN                                                NaN            NaN
# 3       NaN                                                NaN            NaN
# 4    $38.99  10% coupon applied at checkoutSave 10%  with c...       Save 10%
# 5    $35.99  20% coupon applied at checkoutSave 20%  with c...       Save 20%
# 6       NaN                                                NaN            NaN
# 7       NaN  $8.00 coupon applied at checkoutSave $8.00  wi...     Save $8.00
# 8    $39.99  20% coupon applied at checkoutSave 20%  with c...       Save 20%
# 9    $27.99         50% off gift wrap service: code GIFTWRAP50            NaN
# 10   $49.99                                                NaN            NaN

# %% [markdown]
# # Connect to AWS RDS

# %%
config={}
db_name = 'collections'
host = config['host']
user = config['username']
pass1 = config['password']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [46], in <cell line: 3>()
#       1 config={}
#       2 db_name = 'collections'
# ----> 3 host = config['host']
#       4 user = config['username']
#       5 pass1 = config['password']
#
# KeyError: 'host'

# %%
#Creating Connection String to Database
conn = f'mysql+pymysql://{user}:{pass1}@localhost/{db_name}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 2>()
#       1 #Creating Connection String to Database
# ----> 2 conn = f'mysql+pymysql://{user}:{pass1}@localhost/{db_name}'
#
# NameError: name 'user' is not defined

# %%
dbconn = pymysql.connect(host=host, user=user, passwd=pass1, connect_timeout=10)
    with dbconn.cursor() as cur:
        cur.execute(f'Create DATABASE IF NOT EXISTS {db_name}')
        cur.execute(f'use {db_name}')
# Out:
#   Input In [48]
#     with dbconn.cursor() as cur:
#     ^
# IndentationError: unexpected indent

# %%
connection = pymysql.connect( 'database-1.cbrnhoat32p7.us-east-1.rds.amazonaws.com', 'myuser', 'myPass05')
cursor = connection.cursor()
print(cursor)
# Out:
# <pymysql.cursors.Cursor object at 0x120f92a60>

# %%
cursor.execute("select version()")
# Out:
# 1

# %%
data = cursor.fetchone()

# %%
data
# Out:
# ('8.0.28',)

# %%
sql = '''select database collections'''

# %%
cursor.connection.commit()

# %%
sql = '''use collections'''  # use the db
cursor.execute(sql)
# Out:
# 0

# %%
#show the tables in RDs
sql = '''
show tables
'''
cursor.execute(sql)
# Out:
# 1

# %%
cursor.fetchall()
# Out:
# (('items',),)

# %%
sql = '''select * from collections.items'''
cursor.execute(sql)
cursor.connection.commit()
